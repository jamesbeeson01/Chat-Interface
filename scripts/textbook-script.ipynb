# %%
# Import necessary libraries
import os
from dotenv import load_dotenv
import re
import sqlite3
from firecrawl import FirecrawlApp

# Load environment variables from a .env file
# Create a .env file in the root of your project and add your API keys there
# Example .env file:
# FIRECRAWL_API_KEY=your_firecrawl_api_key
# GEMINI_API_KEY=your_gemini_api_key
load_dotenv()

# Get API keys from environment variables
firecrawl_api_key = os.getenv("FIRECRAWL_API_KEY")
gemini_api_key = os.getenv("GEMINI_API_KEY")

# Instantiate firecrawl app
app = FirecrawlApp(api_key=firecrawl_api_key)

# File path for sitemap.txt
sitemap_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts', 'sitemap.txt'))

# Database path for chat.db
db_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'chat.db'))

# %%
import re
import sqlite3

# Regular expression to match the [title](url) pattern
pattern = re.compile(r'\[(.*?)\]\((.*?)\)') # (r'\[(.*?)\]\((.*?)\))')

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Read the sitemap.txt file
try:
    with open(sitemap_path, 'r', encoding='utf-8') as f:
        for line in f:
            match = pattern.match(line.strip())
            if match:
                title = match.group(1) # matches \[(.*?)\]
                url = match.group(2) # matches \((.*?)\)
                # Insert data into the textbook table
                try:
                    cursor.execute("INSERT INTO textbook (title, url) VALUES (?, ?)", (title, url))
                    print(f"Inserted: {title} - {url}")
                except sqlite3.Error as e:
                    print(f"Database error: {e}")
                    print(f"Could not insert: {title} - {url}")

    # Commit the changes to the database
    conn.commit()
    print("Data successfully inserted into the database.")

except FileNotFoundError:
    print(f"Error: {sitemap_path} not found.")
except Exception as e:
    print(f"An error occurred: {e}")

finally:
    # Close the database connection
    if conn:
        conn.close()
        print("Database connection closed.")

# %%
# Install with pip install firecrawl-py
from firecrawl import FirecrawlApp

app = FirecrawlApp(api_key=firecrawl_api_key)

def textbookScrape():
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    try:
        # Select all entries from the textbook table that have a URL but no text
        cursor.execute("SELECT url FROM textbook WHERE url IS NOT NULL AND (text IS NULL OR text = '') LIMIT 10")
        entries = cursor.fetchall()

        print(f"Found {len(entries)} entries to scrape.")

        for entry in entries:
            url = entry[0]
            if url:
                try:
                    print(f"Scraping {url}...")
                    # Scrape the URL and get the markdown content
                    scrape_result = app.scrape_url(url, formats=['markdown'], only_main_content=True, max_age=14400000)
                    markdown_content = scrape_result.markdown
                    
                    # Update the text field in the textbook table
                    cursor.execute("UPDATE textbook SET text = ? WHERE url = ?", (markdown_content, url))
                    print(f"Successfully scraped and updated text for {url}")

                except Exception as e:
                    print(f"Failed to scrape or update for url {url}. Error: {e}")

        # Commit the changes to the database
        conn.commit()
        print("Finished scraping and updating the database.")

    except sqlite3.Error as e:
        print(f"Database error: {e}")

    finally:
        # Close the database connection
        if conn:
            conn.close()
            print("Database connection closed.")

# %% [markdown]
# Where I am right now:
# - Every url is scraped, but has extra text on top
# - For every row in db, remove header.txt
# - The goal is to read loop through the urls and input their content into the database
# - After that is accopmlished, I can use Gemini to provide a summary for each one
#
# For now, I am waiting for a FireScrape help ticket.

# %%
import time

i = 0

while i < 7:
    start_time = time.time()

    textbookScrape()

    elapsed_time = time.time() - start_time

    wait_time = 60 - elapsed_time

    if wait_time > 0:
        time.sleep(wait_time)

    i+=1
# Out:
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/moderate_concept_71_retrieval_practice...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_71_retrieval_practice
# Scraping https://books.byui.edu/science_of_learning/moderate_concept_83_attention...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_71_retrieval_practice
# Scraping https://books.byui.edu/science_of_learning/moderate_concept_83_attention...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_83_attention
# Scraping https://books.byui.edu/science_of_learning/week_8...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_83_attention
# Scraping https://books.byui.edu/science_of_learning/week_8...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/week_8
# Scraping https://books.byui.edu/science_of_learning/maj_72_intellingence...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/week_8
# Scraping https://books.byui.edu/science_of_learning/maj_72_intellingence...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/maj_72_intellingence
# Scraping https://books.byui.edu/science_of_learning/min_76_triarchic_int...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/maj_72_intellingence
# Scraping https://books.byui.edu/science_of_learning/min_76_triarchic_int...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_76_triarchic_int
# Scraping https://books.byui.edu/science_of_learning/bQJcBMEg...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_76_triarchic_int
# Scraping https://books.byui.edu/science_of_learning/bQJcBMEg...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/bQJcBMEg
# Scraping https://books.byui.edu/science_of_learning/blooms_taxonomy...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/bQJcBMEg
# Scraping https://books.byui.edu/science_of_learning/blooms_taxonomy...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/blooms_taxonomy
# Scraping https://books.byui.edu/science_of_learning/mod93_knowledge_cons...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/blooms_taxonomy
# Scraping https://books.byui.edu/science_of_learning/mod93_knowledge_cons...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod93_knowledge_cons
# Scraping https://books.byui.edu/science_of_learning/EQZoGvhN...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod93_knowledge_cons
# Scraping https://books.byui.edu/science_of_learning/EQZoGvhN...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/EQZoGvhN
# Scraping https://books.byui.edu/science_of_learning/adf9g0...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/EQZoGvhN
# Scraping https://books.byui.edu/science_of_learning/adf9g0...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/adf9g0
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/miahmeupqn...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/adf9g0
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/miahmeupqn...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/miahmeupqn
# Scraping https://books.byui.edu/science_of_learning/tiered_instruction...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/miahmeupqn
# Scraping https://books.byui.edu/science_of_learning/tiered_instruction...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/tiered_instruction
# Scraping https://books.byui.edu/science_of_learning/minor_concept_69_tier1_instruction...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/tiered_instruction
# Scraping https://books.byui.edu/science_of_learning/minor_concept_69_tier1_instruction...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_69_tier1_instruction
# Scraping https://books.byui.edu/science_of_learning/minor_concept_63_partnership_with_parents...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_69_tier1_instruction
# Scraping https://books.byui.edu/science_of_learning/minor_concept_63_partnership_with_parents...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_63_partnership_with_parents
# Scraping https://books.byui.edu/science_of_learning/MVkRIXqp...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_63_partnership_with_parents
# Scraping https://books.byui.edu/science_of_learning/MVkRIXqp...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/MVkRIXqp
# Scraping https://books.byui.edu/science_of_learning/minor_concept_613_ten_basics_of_classroom_management...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/MVkRIXqp
# Scraping https://books.byui.edu/science_of_learning/minor_concept_613_ten_basics_of_classroom_management...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_613_ten_basics_of_classroom_management
# Scraping https://books.byui.edu/science_of_learning/zLBeHvKu...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_613_ten_basics_of_classroom_management
# Scraping https://books.byui.edu/science_of_learning/zLBeHvKu...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/zLBeHvKu
# Scraping https://books.byui.edu/science_of_learning/min_41_trait_anxiety...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/zLBeHvKu
# Scraping https://books.byui.edu/science_of_learning/min_41_trait_anxiety...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_41_trait_anxiety
# Scraping https://books.byui.edu/science_of_learning/csXjDwea...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_41_trait_anxiety
# Scraping https://books.byui.edu/science_of_learning/csXjDwea...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/csXjDwea
# Scraping https://books.byui.edu/science_of_learning/mod_self_actualizati...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/csXjDwea
# Scraping https://books.byui.edu/science_of_learning/mod_self_actualizati...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod_self_actualizati
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/scientific_validity_...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod_self_actualizati
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/scientific_validity_...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/scientific_validity_
# Scraping https://books.byui.edu/science_of_learning/bXFfMrWA...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/scientific_validity_
# Scraping https://books.byui.edu/science_of_learning/bXFfMrWA...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/bXFfMrWA
# Scraping https://books.byui.edu/science_of_learning/kcbinvIK...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/bXFfMrWA
# Scraping https://books.byui.edu/science_of_learning/kcbinvIK...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/kcbinvIK
# Scraping https://books.byui.edu/science_of_learning/minor_concept_52_discrimination_psychology...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/kcbinvIK
# Scraping https://books.byui.edu/science_of_learning/minor_concept_52_discrimination_psychology...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_52_discrimination_psychology
# Scraping https://books.byui.edu/science_of_learning/HuYoPuwW...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_52_discrimination_psychology
# Scraping https://books.byui.edu/science_of_learning/HuYoPuwW...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/HuYoPuwW
# Scraping https://books.byui.edu/science_of_learning/mod_63_school_cultur...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/HuYoPuwW
# Scraping https://books.byui.edu/science_of_learning/mod_63_school_cultur...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod_63_school_cultur
# Scraping https://books.byui.edu/science_of_learning/min_64_the_ripple_ef...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mod_63_school_cultur
# Scraping https://books.byui.edu/science_of_learning/min_64_the_ripple_ef...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_64_the_ripple_ef
# Scraping https://books.byui.edu/science_of_learning/mHmnTjyH...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_64_the_ripple_ef
# Scraping https://books.byui.edu/science_of_learning/mHmnTjyH...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mHmnTjyH
# Scraping https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/mHmnTjyH
# Scraping https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that...
# Failed to scrape or update for url https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that. Error: Request Timeout: Failed to scrape URL as the request timed out. Request timed out - No additional error details provided.
# Scraping https://books.byui.edu/science_of_learning/minor_concept_610_talk_procedural_content_control...
# Failed to scrape or update for url https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that. Error: Request Timeout: Failed to scrape URL as the request timed out. Request timed out - No additional error details provided.
# Scraping https://books.byui.edu/science_of_learning/minor_concept_610_talk_procedural_content_control...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_610_talk_procedural_content_control
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_610_talk_procedural_content_control
# Finished scraping and updating the database.
# Database connection closed.
# Found 10 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that
# Scraping https://books.byui.edu/science_of_learning/min_611_non_verbal_c...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_68_imessages_i_feel_that
# Scraping https://books.byui.edu/science_of_learning/min_611_non_verbal_c...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_611_non_verbal_c
# Scraping https://books.byui.edu/science_of_learning/nkYbzvtk...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_611_non_verbal_c
# Scraping https://books.byui.edu/science_of_learning/nkYbzvtk...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/nkYbzvtk
# Scraping https://books.byui.edu/science_of_learning/Gender_Psychology...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/nkYbzvtk
# Scraping https://books.byui.edu/science_of_learning/Gender_Psychology...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/Gender_Psychology
# Scraping https://books.byui.edu/science_of_learning/minor_concept_77_prototype...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/Gender_Psychology
# Scraping https://books.byui.edu/science_of_learning/minor_concept_77_prototype...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_77_prototype
# Scraping https://books.byui.edu/science_of_learning/GvGYFCiY...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_77_prototype
# Scraping https://books.byui.edu/science_of_learning/GvGYFCiY...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/GvGYFCiY
# Scraping https://books.byui.edu/science_of_learning/RdVJuvhC...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/GvGYFCiY
# Scraping https://books.byui.edu/science_of_learning/RdVJuvhC...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/RdVJuvhC
# Scraping https://books.byui.edu/science_of_learning/min_83_cognition...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/RdVJuvhC
# Scraping https://books.byui.edu/science_of_learning/min_83_cognition...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_83_cognition
# Scraping https://books.byui.edu/science_of_learning/moderate_concept_112_phonics...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/min_83_cognition
# Scraping https://books.byui.edu/science_of_learning/moderate_concept_112_phonics...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_112_phonics
# Scraping https://books.byui.edu/science_of_learning/the_great_inquiry_learning_debate...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/moderate_concept_112_phonics
# Scraping https://books.byui.edu/science_of_learning/the_great_inquiry_learning_debate...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/the_great_inquiry_learning_debate
# Finished scraping and updating the database.
# Database connection closed.
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/the_great_inquiry_learning_debate
# Finished scraping and updating the database.
# Database connection closed.
# Found 5 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/zYcdXesX...
# Found 5 entries to scrape.
# Scraping https://books.byui.edu/science_of_learning/zYcdXesX...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/zYcdXesX
# Scraping https://books.byui.edu/science_of_learning/minor_concept_92_information_processing...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/zYcdXesX
# Scraping https://books.byui.edu/science_of_learning/minor_concept_92_information_processing...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_92_information_processing
# Scraping https://books.byui.edu/science_of_learning/TowQutZE...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/minor_concept_92_information_processing
# Scraping https://books.byui.edu/science_of_learning/TowQutZE...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/TowQutZE
# Scraping https://books.byui.edu/science_of_learning/additional_optional_readings...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/TowQutZE
# Scraping https://books.byui.edu/science_of_learning/additional_optional_readings...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/additional_optional_readings
# Scraping https://books.byui.edu/author/13026294...
# Successfully scraped and updated text for https://books.byui.edu/science_of_learning/additional_optional_readings
# Scraping https://books.byui.edu/author/13026294...
# Successfully scraped and updated text for https://books.byui.edu/author/13026294
# Finished scraping and updating the database.
# Database connection closed.
# Successfully scraped and updated text for https://books.byui.edu/author/13026294
# Finished scraping and updating the database.
# Database connection closed.
# Found 0 entries to scrape.
# Finished scraping and updating the database.
# Database connection closed.
# Found 0 entries to scrape.
# Finished scraping and updating the database.
# Database connection closed.
# Found 0 entries to scrape.
# Finished scraping and updating the database.
# Database connection closed.
# Found 0 entries to scrape.
# Finished scraping and updating the database.
# Database connection closed.

# %% [markdown]
# Remove the header

# %%
with open('header.txt') as h:
    header = h.read()

    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

     # Select all entries from the textbook table that have a URL but no text
    cursor.execute("SELECT text FROM textbook WHERE cleanText IS NULL")
    entries = cursor.fetchall()

    # print(header)

    for entry in entries:
        try:
            text = entry[0].replace("’", "'")
            text = text.split(header)[1]
            text = text.split("This content was previously published as follows:")[0]

            cursor.execute("UPDATE textbook SET cleanText = ? WHERE text = ?", (text, entry[0]))
        except:
            print("Didn't work")
    
    conn.commit()
    conn.close()
# Out:
# Didn't work
# Didn't work

# %% [markdown]
# Remove the footer

# %%
# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

try:
    # Select all entries from the textbook table that have a URL but no text
    cursor.execute("SELECT cleanText FROM textbook WHERE cleanText IS NOT NULL")
    entries = cursor.fetchall()

    try:
        for entry in entries:
            original = entry[0]
            
            text = original.replace("\n\n![](https://books.byui.edu/images/licenses/cc.svg)![](https://books.byui.edu/images/licenses/by.svg)![](https://books.byui.edu/images/licenses/sa.svg)This work is released under a CC BY-SA license, which means that\nyou are free to do with it as you please as long as you (1) properly\nattribute it and (2) share any derivative works under an open\nlicense.\n\n","")

            cursor.execute("UPDATE textbook SET cleanText = ? WHERE cleanText = ?", [text, original])
    except Exception as e:
        print(e)

except Exception as e:
    print(e)

conn.commit()
conn.close()

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 from google import genai
#       3 client = genai.Client()
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents="Explain how AI works in a few words",
#       8 )
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)
